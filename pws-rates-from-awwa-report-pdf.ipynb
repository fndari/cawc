# %% [markdown]
# # Obtaining Public Water Service rates

# %% [markdown]
# The PWS rates information is given in the challenge dataset #10. After looking at it and realizing that only a small fraction of the providers had usable information, we tried to find a more complete source for this data.
#
# Following Greg's suggestions, we found the data in a report titled "Water Rate Survey 2017", authored by the American Water Works Association (California-Nevada section), Raftelis, and California Data Collaborative. The following evening, we were notified that the same table was also available as a CSV file. Since I had already analyzed the PDF, I decided it could be useful knowledge for other circumstances where the machine-readable data is not available.

# %%
from tabula import read_pdf
import pandas as pd

# %%
df = read_pdf('CA-NV_RateSurvey-2017_final.pdf', pages='19-27')
df.head()
# Out:
#                       Unnamed: 0  Effective      Unnamed: 2 Billing  \
# 0         Water Service Provider       Date  Bill Frequency    Unit
# 1  Alameda County Water District   3/1/2018      Bi-Monthly     ccf
# 2            Amador Water Agency  10/1/2017         Monthly     ccf
# 3       American Canyon  City Of   6/1/2017         Monthly     ccf
# 4                Anaheim City of   2/1/2016         Monthly     ccf
#
#   Average Monthly       Rate Monthly Fixed Monthly Variable   Total
# 0    Custom Usage  Structure        Charge           Charge  Charge
# 1               9    Uniform         26.16            36.49   62.66
# 2               8    Uniform         25.08            20.64   45.72
# 3               9     Tiered           6.4            49.23   55.63
# 4              10    Uniform         12.97             5.19   18.16

# %% [markdown]
# We can see that there are some spurious header rows among the real data.
# Usually, we can pass the line numbers to skip to the `read_csv()` function (in Tabula-py, exposed through the `pandas_option` kwarg parameter). This doesn't work here because the header is repeated on each page of the PDF; Tabula-py seems to be applying `pandas_options` only to the full (multipage) intermediate CSV table.

# %%
def read_pdf_skip_header(path, pages):
    return read_pdf(path, pages=pages, pandas_options={'skiprows': [1]})

def is_spurious_header(df):
    # these values are just examples, any other column would work
    return df['Effective'].isin(['Effective', 'Date'])

def remove_spurious_header_rows(df):
    rows = df.loc[is_spurious_header].index
    return df.drop(rows)

# %%
(read_pdf_skip_header('CA-NV_RateSurvey-2017_final.pdf', pages='19-27')
 .loc[is_spurious_header]
)
# Out:
#                  Unnamed: 0  Effective      Unnamed: 2  Billing  \
# 37                      NaN  Effective             NaN  Billing
# 38   Water Service Provider       Date  Bill Frequency     Unit
# 76                      NaN  Effective             NaN  Billing
# 77   Water Service Provider       Date  Bill Frequency     Unit
# 115                     NaN  Effective             NaN  Billing
# 116  Water Service Provider       Date  Bill Frequency     Unit
# 154                     NaN  Effective             NaN  Billing
# 155  Water Service Provider       Date  Bill Frequency     Unit
# 192                     NaN  Effective             NaN  Billing
# 193  Water Service Provider       Date  Bill Frequency     Unit
# 231                     NaN  Effective             NaN  Billing
# 232  Water Service Provider       Date  Bill Frequency     Unit
# 270                     NaN  Effective             NaN  Billing
# 271  Water Service Provider       Date  Bill Frequency     Unit
# 309                     NaN  Effective             NaN  Billing
# 310  Water Service Provider       Date  Bill Frequency     Unit
#
#      Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 37   Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 38      Custom Usage  Structure         Charge            Charge  Charge
# 76   Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 77      Custom Usage  Structure         Charge            Charge  Charge
# 115  Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 116     Custom Usage  Structure         Charge            Charge  Charge
# 154  Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 155     Custom Usage  Structure         Charge            Charge  Charge
# 192  Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 193     Custom Usage  Structure         Charge            Charge  Charge
# 231  Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 232     Custom Usage  Structure         Charge            Charge  Charge
# 270  Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 271     Custom Usage  Structure         Charge            Charge  Charge
# 309  Average Monthly       Rate  Monthly Fixed  Monthly Variable   Total
# 310     Custom Usage  Structure         Charge            Charge  Charge

# %% [markdown]
# We could select the spurious header rows and then reject them, based on ad-hoc values:

# %%
def remove_spurious_header_rows(df):
    rows = df.loc[is_spurious_header].index
    return df.drop(rows)

# %%
(read_pdf_skip_header('CA-NV_RateSurvey-2017_final.pdf', pages='19-27')
 .pipe(remove_spurious_header_rows)
 .loc[is_spurious_header]
)
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Effective, Unnamed: 2, Billing, Average Monthly, Rate, Monthly Fixed, Monthly Variable, Total]
# Index: []

# %% [markdown]
# A more solid approach would be to implement the multi-page reading functionality ourselves, so that `pandas_options` is applied on each page as intended, and then concatenating the single-page tables using `pd.concat`.
# For the general case, this approach also offers the possibility of implementing per-page adjustments, if necessary.
# It is possible that this is slower for very large tables, so flexibility/performance tradeoffs should be considered.

# %%
def read_pdf_separate_pages(path, pages, **pandas_options):
     return pd.concat((read_pdf(path, pages=[page],
                                pandas_options=pandas_options)
                       for page in pages), ignore_index=True)

# %%
df = read_pdf_separate_pages('CA-NV_RateSurvey-2017_final.pdf', pages=range(17, 28), skiprows=[1])
df.loc[is_spurious_header]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0, Effective, Unnamed: 2, Billing, Average Monthly, Rate, Monthly Fixed, Monthly Variable, Total]
# Index: []

# %%
df
# Out:
#                                             Unnamed: 0   Effective  \
# 0                        Alameda County Water District    3/1/2018
# 1                                  Amador Water Agency   10/1/2017
# 2                             American Canyon  City Of    6/1/2017
# 3                                      Anaheim City of    2/1/2016
# 4                                     Antioch  City Of    7/1/2017
# 5                   Apple Valley Ranchos Water Company    1/1/2017
# 6                                     Arcadia  City Of    4/1/2017
# 7                                      Arcata  City Of   10/1/2017
# 8                 Arrowbear Park County Water District  12/19/2016
# 9                               Arroyo Grande  City Of    8/9/2017
# 10                                Bakersfield  City Of   10/1/2017
# 11                              Bear State Water Works   8/15/2017
# 12            Bellflower-Somerset Mutual Water Company   10/1/2014
# 13                                    Benicia  City Of    7/1/2017
# 14                               Beverly Hills City of    7/3/2017
# 15            Big Bear City Community Service District    7/1/2017
# 16                              Big Bear Lake  City Of    4/1/2017
# 17                                     Blythe  City Of    7/1/2017
# 18                                    Brawley  City Of    7/1/2018
# 19                                       Brea  City Of    7/1/2017
# 20                                   Brentwood City of    7/1/2016
# 21                                 Buena Park  City Of    1/1/2018
# 22                                     Burbank City of    1/2/2017
# 23                                  Burlingame City Of    1/1/2017
# 24                     Calaveras County Water District    9/1/2017
# 25                 Calaveras Public Utilities District    7/1/2016
# 26                                   Calexico  City Of    8/1/2008
# 27   California American Water Company - Sacramento...    1/1/2018
# 28          California American Water Ventura District   1/13/2017
# 29    California Water Service Company Antelope Valley    1/1/2017
# ..                                                 ...         ...
# 293                                    Upland  City of    4/1/2018
# 294                                 Vacaville  City Of    1/1/2018
# 295                             Valencia Water Company    1/1/2018
# 296            Vallejo  City Of - Vallejo Service Area    6/9/2017
# 297               Vallejo City Of - Lakes Service Area    6/9/2017
# 298                       Valley County Water District    1/1/2018
# 299       Valley Estates Properties Owners Association    1/1/2017
# 300                  Valley Of The Moon Water District    2/1/2018
# 301                               Vaughn Water Company    1/1/2018
# 302                                    Ventura City Of    7/1/2017
# 303  Ventura County Waterworks District No 01 - Moo...   3/15/2017
# 304                                    Vernon  City Of    3/1/2015
# 305                         Victorville Water District    7/1/2016
# 306                       Virgin Valley Water District   4/20/2015
# 307                          Vista Irrigation District    7/1/2017
# 308                       Walnut Valley Water District    1/1/2017
# 309                               Watsonville  City Of    7/1/2017
# 310                           West Sacramento  City Of    7/1/2021
# 311                        West San Martin Water Works   7/17/2017
# 312                         West Valley Water District    1/1/2015
# 313                         Westborough Water District    9/8/2016
# 314                   Western Municipal Water District    1/1/2018
# 315              Westhaven Community Services District    7/1/2017
# 316                              Westminister  City Of   11/9/2017
# 317                                  Whittier  City Of    8/1/2017
# 318                                   Windsor  Town Of    7/1/2017
# 319                                  Woodland  City Of    1/1/2021
# 320                         Yorba Linda Water District    8/1/2017
# 321                                     Yreka  City Of   10/1/2012
# 322                      Yucaipa Valley Water District    3/7/2017
#
#      Unnamed: 2 Billing  Average Monthly     Rate  Monthly Fixed  \
# 0    Bi-Monthly     ccf                9  Uniform          26.16
# 1       Monthly     ccf                8  Uniform          25.08
# 2       Monthly     ccf                9   Tiered           6.40
# 3       Monthly     ccf               10  Uniform          12.97
# 4       Monthly     ccf               10   Tiered          21.20
# 5       monthly     ccf               15   Tiered          34.73
# 6     Bimonthly     ccf               19   Tiered          10.17
# 7       Monthly     ccf                4   Tiered          12.16
# 8       Monthly     ccf               15   Tiered          27.50
# 9       Monthly     ccf                9   Tiered          34.34
# 10      Monthly     ccf               20  Uniform          11.46
# 11      Monthly    kgal               15   Tiered           4.17
# 12    bimonthly     ccf                9  Uniform          14.18
# 13   Bi-Monthly     ccf                7  Uniform          15.08
# 14    Bimonthly     ccf               11   Tiered          21.68
# 15   Bi-Monthly     ccf                6   Tiered          36.98
# 16   Bi-Monthly     ccf               15   Tiered          45.60
# 17      Monthly     ccf               15  Uniform          10.66
# 18      Monthly    kgal               14  Uniform          38.24
# 19      Monthly     ccf               10   Tiered          15.93
# 20      monthly     ccf               11   Tiered          29.83
# 21      Monthly    kgal               11  Uniform          38.61
# 22      monthly     ccf                9   Tiered          12.29
# 23   Bi-Monthly    kgal                6   Tiered          36.36
# 24   Bi-Monthly     ccf               15   Tiered          85.17
# 25      Monthly    kgal               15   Tiered          39.73
# 26      Monthly     ccf               13   Tiered          43.89
# 27      Monthly    kgal               15   Tiered          19.84
# 28      Monthly    kgal               15   Tiered          14.73
# 29      monthly     ccf               15   Tiered          31.02
# ..          ...     ...              ...      ...            ...
# 293  Bi-Monthly     ccf               16   Tiered          29.70
# 294     Monthly     ccf               12  Uniform          21.61
# 295     Monthly     ccf               11  Uniform          17.19
# 296     Monthly     ccf               15   Tiered          19.45
# 297     Monthly     ccf               15   Tiered          41.08
# 298  Bi-Monthly     ccf               10   Tiered          14.91
# 299     Monthly    kgal               15   Tiered          27.50
# 300  Bi-Monthly    kgal                8   Tiered          12.80
# 301     Monthly     ccf               35   Tiered          39.38
# 302  Bi-Monthly     ccf               15   Tiered          16.84
# 303     Monthly     ccf               16   Tiered          10.41
# 304     Monthly     ccf                5  Uniform          11.29
# 305     Monthly     ccf               15  Uniform          11.78
# 306     Monthly    kgal               15   Tiered          35.00
# 307     Monthly     ccf                9   Tiered          37.05
# 308     monthly     ccf               14   Tiered          19.43
# 309     Monthly     ccf                9   Tiered          25.80
# 310     Monthly     ccf               11  Uniform          24.61
# 311     Monthly     ccf               15   Tiered          23.45
# 312     Monthly     ccf               20   Tiered          22.21
# 313     Monthly     ccf                5  Uniform          17.70
# 314     Monthly     ccf               15   Budget          34.67
# 315     Monthly    kgal               15  Uniform          49.40
# 316  Bi-Monthly     ccf               10   Tiered           7.08
# 317  Bi-Monthly     ccf               10   Tiered          20.18
# 318  Bi-Monthly    kgal                8   Tiered           5.62
# 319     Monthly     ccf                9   Tiered          55.65
# 320     Monthly     ccf               17  Uniform          19.45
# 321     Monthly    kgal                9   Tiered          41.08
# 322     Monthly    kgal               19   Tiered          14.00
#
#      Monthly Variable   Total
# 0               36.49   62.66
# 1               20.64   45.72
# 2               49.23   55.63
# 3                5.19   18.16
# 4               32.52   53.72
# 5               63.14   97.87
# 6               32.52   42.69
# 7               14.09   26.25
# 8               58.50   86.00
# 9               36.60   70.94
# 10              21.37   32.83
# 11              14.60   18.77
# 12              16.29   30.47
# 13              29.48   44.56
# 14              52.83   74.51
# 15              12.17   49.15
# 16              33.46   79.06
# 17              29.55   40.21
# 18              18.95   57.19
# 19              36.99   52.92
# 20              43.82   73.65
# 21              17.49   56.10
# 22              11.55   39.37
# 23              43.58   79.94
# 24              11.52   96.69
# 25              11.55   51.28
# 26               0.00   43.89
# 27              46.70   66.54
# 28              58.74   73.47
# 29              65.35   96.37
# ..                ...     ...
# 293             31.94   61.64
# 294             20.36   41.97
# 295             19.94   37.13
# 296             65.90   85.34
# 297            197.37  238.44
# 298             13.68   28.59
# 299            308.55  336.05
# 300             36.74   49.54
# 301             11.36   50.74
# 302             74.59   91.44
# 303             57.08   67.49
# 304              9.90   21.19
# 305             25.83   37.61
# 306             25.05   60.05
# 307             39.80   76.85
# 308             43.66   63.09
# 309             30.80   56.60
# 310             27.61   52.22
# 311             38.76   62.21
# 312             45.25   67.46
# 313             34.35   52.05
# 314             35.77   70.44
# 315            157.87  207.27
# 316             28.23   35.30
# 317             19.36   39.53
# 318             23.22   28.84
# 319             37.12   92.77
# 320             47.15   66.60
# 321             12.86   53.94
# 322             20.58   34.58
#
# [323 rows x 9 columns]

# %%
COLUMNS = [
    'provider_name',
    'effective_date',
    'billing_freq',
    'billing_unit',
    'avg_monthly_custom_usage',
    'rate_structure',
    'monthly_fixed_charge',
    'monthly_variable_charge',
    'total_charge'
]

CURRENCY_TYPE = float  # never do this in production!!!

DTYPES = {
    'provider_name': 'category',
    'billing_freq': 'category',
    'billing_unit': 'category',
    'avg_monthly_custom_usage': int,  # TODO we should check this
    'rate_structure': 'category',
    'monthly_fixed_charge': CURRENCY_TYPE,
    'monthly_variable_charge': CURRENCY_TYPE,
    'total_charge': CURRENCY_TYPE,   
}

# %% [markdown]
# The pandas Categorical dtype is roughly equivalent to an enum, and should be used whenever values can only take a finite number of options. The `uniformize_entries` is needed to normalize the various options for columns such as `billing_freq`, `billing_unit` and `rate_structure`, where the input values were formatted inconsistently.

# %%
def uniformize_entries(col):
    return (col
            .astype(str)
            .str.replace('-', '')
            .str.title()
           )

def clean(df):
    # never modify in-place!
    df = df.copy()
    df.columns = COLUMNS
    return (df
            .assign(rate_structure=lambda d: uniformize_entries(d.rate_structure),
                    billing_freq=lambda d: uniformize_entries(d.billing_freq),
                    provider_name=lambda d: uniformize_entries(d.provider_name),
                    effective_date=lambda d: pd.to_datetime(d.effective_date))
            .astype(DTYPES)
           )

# %%
df = clean(df)
df
# Out:
#                                          provider_name effective_date  \
# 0                        Alameda County Water District     2018-03-01
# 1                                  Amador Water Agency     2017-10-01
# 2                             American Canyon  City Of     2017-06-01
# 3                                      Anaheim City Of     2016-02-01
# 4                                     Antioch  City Of     2017-07-01
# 5                   Apple Valley Ranchos Water Company     2017-01-01
# 6                                     Arcadia  City Of     2017-04-01
# 7                                      Arcata  City Of     2017-10-01
# 8                 Arrowbear Park County Water District     2016-12-19
# 9                               Arroyo Grande  City Of     2017-08-09
# 10                                Bakersfield  City Of     2017-10-01
# 11                              Bear State Water Works     2017-08-15
# 12             Bellflowersomerset Mutual Water Company     2014-10-01
# 13                                    Benicia  City Of     2017-07-01
# 14                               Beverly Hills City Of     2017-07-03
# 15            Big Bear City Community Service District     2017-07-01
# 16                              Big Bear Lake  City Of     2017-04-01
# 17                                     Blythe  City Of     2017-07-01
# 18                                    Brawley  City Of     2018-07-01
# 19                                       Brea  City Of     2017-07-01
# 20                                   Brentwood City Of     2016-07-01
# 21                                 Buena Park  City Of     2018-01-01
# 22                                     Burbank City Of     2017-01-02
# 23                                  Burlingame City Of     2017-01-01
# 24                     Calaveras County Water District     2017-09-01
# 25                 Calaveras Public Utilities District     2016-07-01
# 26                                   Calexico  City Of     2008-08-01
# 27   California American Water Company  Sacramento ...     2018-01-01
# 28          California American Water Ventura District     2017-01-13
# 29    California Water Service Company Antelope Valley     2017-01-01
# ..                                                 ...            ...
# 293                                    Upland  City Of     2018-04-01
# 294                                 Vacaville  City Of     2018-01-01
# 295                             Valencia Water Company     2018-01-01
# 296             Vallejo  City Of  Vallejo Service Area     2017-06-09
# 297                Vallejo City Of  Lakes Service Area     2017-06-09
# 298                       Valley County Water District     2018-01-01
# 299       Valley Estates Properties Owners Association     2017-01-01
# 300                  Valley Of The Moon Water District     2018-02-01
# 301                               Vaughn Water Company     2018-01-01
# 302                                    Ventura City Of     2017-07-01
# 303  Ventura County Waterworks District No 01  Moor...     2017-03-15
# 304                                    Vernon  City Of     2015-03-01
# 305                         Victorville Water District     2016-07-01
# 306                       Virgin Valley Water District     2015-04-20
# 307                          Vista Irrigation District     2017-07-01
# 308                       Walnut Valley Water District     2017-01-01
# 309                               Watsonville  City Of     2017-07-01
# 310                           West Sacramento  City Of     2021-07-01
# 311                        West San Martin Water Works     2017-07-17
# 312                         West Valley Water District     2015-01-01
# 313                         Westborough Water District     2016-09-08
# 314                   Western Municipal Water District     2018-01-01
# 315              Westhaven Community Services District     2017-07-01
# 316                              Westminister  City Of     2017-11-09
# 317                                  Whittier  City Of     2017-08-01
# 318                                   Windsor  Town Of     2017-07-01
# 319                                  Woodland  City Of     2021-01-01
# 320                         Yorba Linda Water District     2017-08-01
# 321                                     Yreka  City Of     2012-10-01
# 322                      Yucaipa Valley Water District     2017-03-07
#
#     billing_freq billing_unit  avg_monthly_custom_usage rate_structure  \
# 0      Bimonthly          ccf                         9        Uniform
# 1        Monthly          ccf                         8        Uniform
# 2        Monthly          ccf                         9         Tiered
# 3        Monthly          ccf                        10        Uniform
# 4        Monthly          ccf                        10         Tiered
# 5        Monthly          ccf                        15         Tiered
# 6      Bimonthly          ccf                        19         Tiered
# 7        Monthly          ccf                         4         Tiered
# 8        Monthly          ccf                        15         Tiered
# 9        Monthly          ccf                         9         Tiered
# 10       Monthly          ccf                        20        Uniform
# 11       Monthly         kgal                        15         Tiered
# 12     Bimonthly          ccf                         9        Uniform
# 13     Bimonthly          ccf                         7        Uniform
# 14     Bimonthly          ccf                        11         Tiered
# 15     Bimonthly          ccf                         6         Tiered
# 16     Bimonthly          ccf                        15         Tiered
# 17       Monthly          ccf                        15        Uniform
# 18       Monthly         kgal                        14        Uniform
# 19       Monthly          ccf                        10         Tiered
# 20       Monthly          ccf                        11         Tiered
# 21       Monthly         kgal                        11        Uniform
# 22       Monthly          ccf                         9         Tiered
# 23     Bimonthly         kgal                         6         Tiered
# 24     Bimonthly          ccf                        15         Tiered
# 25       Monthly         kgal                        15         Tiered
# 26       Monthly          ccf                        13         Tiered
# 27       Monthly         kgal                        15         Tiered
# 28       Monthly         kgal                        15         Tiered
# 29       Monthly          ccf                        15         Tiered
# ..           ...          ...                       ...            ...
# 293    Bimonthly          ccf                        16         Tiered
# 294      Monthly          ccf                        12        Uniform
# 295      Monthly          ccf                        11        Uniform
# 296      Monthly          ccf                        15         Tiered
# 297      Monthly          ccf                        15         Tiered
# 298    Bimonthly          ccf                        10         Tiered
# 299      Monthly         kgal                        15         Tiered
# 300    Bimonthly         kgal                         8         Tiered
# 301      Monthly          ccf                        35         Tiered
# 302    Bimonthly          ccf                        15         Tiered
# 303      Monthly          ccf                        16         Tiered
# 304      Monthly          ccf                         5        Uniform
# 305      Monthly          ccf                        15        Uniform
# 306      Monthly         kgal                        15         Tiered
# 307      Monthly          ccf                         9         Tiered
# 308      Monthly          ccf                        14         Tiered
# 309      Monthly          ccf                         9         Tiered
# 310      Monthly          ccf                        11        Uniform
# 311      Monthly          ccf                        15         Tiered
# 312      Monthly          ccf                        20         Tiered
# 313      Monthly          ccf                         5        Uniform
# 314      Monthly          ccf                        15         Budget
# 315      Monthly         kgal                        15        Uniform
# 316    Bimonthly          ccf                        10         Tiered
# 317    Bimonthly          ccf                        10         Tiered
# 318    Bimonthly         kgal                         8         Tiered
# 319      Monthly          ccf                         9         Tiered
# 320      Monthly          ccf                        17        Uniform
# 321      Monthly         kgal                         9         Tiered
# 322      Monthly         kgal                        19         Tiered
#
#      monthly_fixed_charge  monthly_variable_charge  total_charge
# 0                   26.16                    36.49         62.66
# 1                   25.08                    20.64         45.72
# 2                    6.40                    49.23         55.63
# 3                   12.97                     5.19         18.16
# 4                   21.20                    32.52         53.72
# 5                   34.73                    63.14         97.87
# 6                   10.17                    32.52         42.69
# 7                   12.16                    14.09         26.25
# 8                   27.50                    58.50         86.00
# 9                   34.34                    36.60         70.94
# 10                  11.46                    21.37         32.83
# 11                   4.17                    14.60         18.77
# 12                  14.18                    16.29         30.47
# 13                  15.08                    29.48         44.56
# 14                  21.68                    52.83         74.51
# 15                  36.98                    12.17         49.15
# 16                  45.60                    33.46         79.06
# 17                  10.66                    29.55         40.21
# 18                  38.24                    18.95         57.19
# 19                  15.93                    36.99         52.92
# 20                  29.83                    43.82         73.65
# 21                  38.61                    17.49         56.10
# 22                  12.29                    11.55         39.37
# 23                  36.36                    43.58         79.94
# 24                  85.17                    11.52         96.69
# 25                  39.73                    11.55         51.28
# 26                  43.89                     0.00         43.89
# 27                  19.84                    46.70         66.54
# 28                  14.73                    58.74         73.47
# 29                  31.02                    65.35         96.37
# ..                    ...                      ...           ...
# 293                 29.70                    31.94         61.64
# 294                 21.61                    20.36         41.97
# 295                 17.19                    19.94         37.13
# 296                 19.45                    65.90         85.34
# 297                 41.08                   197.37        238.44
# 298                 14.91                    13.68         28.59
# 299                 27.50                   308.55        336.05
# 300                 12.80                    36.74         49.54
# 301                 39.38                    11.36         50.74
# 302                 16.84                    74.59         91.44
# 303                 10.41                    57.08         67.49
# 304                 11.29                     9.90         21.19
# 305                 11.78                    25.83         37.61
# 306                 35.00                    25.05         60.05
# 307                 37.05                    39.80         76.85
# 308                 19.43                    43.66         63.09
# 309                 25.80                    30.80         56.60
# 310                 24.61                    27.61         52.22
# 311                 23.45                    38.76         62.21
# 312                 22.21                    45.25         67.46
# 313                 17.70                    34.35         52.05
# 314                 34.67                    35.77         70.44
# 315                 49.40                   157.87        207.27
# 316                  7.08                    28.23         35.30
# 317                 20.18                    19.36         39.53
# 318                  5.62                    23.22         28.84
# 319                 55.65                    37.12         92.77
# 320                 19.45                    47.15         66.60
# 321                 41.08                    12.86         53.94
# 322                 14.00                    20.58         34.58
#
# [323 rows x 9 columns]

# %% [markdown]
# # TODO
#
# - Join with the Water Provider info table (`WPSID`, etc)
#
#
# # Notes
# - This table probably has cities from Nevada as well

# %%
from cawc import PATH_DATA
PATH_DATA
# Out:
# PosixPath('/data/datasets/cawc')
