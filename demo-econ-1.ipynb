# %% [markdown]
# # Demographic and economic data #1
#
# The demographic information comes from "SELECTED ECONOMIC CHARACTERISTICS
# 2012-2016 American Community Survey 5-Year Estimates", obtained at this URL: https://factfinder.census.gov/faces/tableservices/jsf/pages/productview.xhtml?pid=ACS_16_5YR_DP03&prodType=table.
#
# We're interested in having some basic economic and demographic data, to quantify the impact that unaffordable water prices can cause.
#
# The other notebook, `demo-2`, contains a very similar procedure for the household income data, after I realized that it was not included in the first table I exported.

# %%
import geopandas as gpd
import pandas as pd
import numpy as np

import cawc

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2

# %%
PATH = cawc.PATH_DATA / 'sec-2016'

data = pd.read_csv(PATH / 'ACS_16_5YR_DP03.csv')
data.sample(10)
# Out:
#                     GEO.id     GEO.id2  \
# 2775  1400000US06037533901  6037533901
# 1976  1400000US06037240700  6037240700
# 6573  1400000US06077004404  6077004404
# 3225  1400000US06037650001  6037650001
# 5346  1400000US06071001308  6071001308
# 5835  1400000US06073008358  6073008358
# 4298  1400000US06059099217  6059099217
# 5222  1400000US06067009309  6067009309
# 7945  1400000US06111006700  6111006700
# 4762  1400000US06065043308  6065043308
#
#                                       GEO.display-label  HC03_VC03  HC04_VC03  \
# 2775  Census Tract 5339.01, Los Angeles County, Cali...       4517        NaN
# 1976  Census Tract 2407, Los Angeles County, California       4646        NaN
# 6573  Census Tract 44.04, San Joaquin County, Califo...       2564        NaN
# 3225  Census Tract 6500.01, Los Angeles County, Cali...       4970        NaN
# 5346  Census Tract 13.08, San Bernardino County, Cal...       3683        NaN
# 5835   Census Tract 83.58, San Diego County, California       6488        NaN
# 4298     Census Tract 992.17, Orange County, California       2061        NaN
# 5222  Census Tract 93.09, Sacramento County, California       2028        NaN
# 7945        Census Tract 67, Ventura County, California       2669        NaN
# 4762  Census Tract 433.08, Riverside County, California       2127        NaN
#
#       HC03_VC04  HC04_VC04  HC03_VC05  HC04_VC05  HC03_VC06     ...      \
# 2775       66.2        3.9       66.2        3.9       59.1     ...
# 1976       58.0        3.8       58.0        3.8       52.1     ...
# 6573       63.4        4.2       63.4        4.2       56.5     ...
# 3225       57.5        3.8       57.5        3.8       55.1     ...
# 5346       68.5        4.1       68.5        4.1       58.1     ...
# 5835       70.9        4.0       70.2        4.2       64.5     ...
# 4298       65.5        3.5       65.5        3.5       63.2     ...
# 5222       53.1        4.1       52.6        4.1       45.2     ...
# 7945       67.1        6.9       66.8        6.9       60.7     ...
# 4762       58.7        5.5       58.7        5.5       42.3     ...
#
#       HC03_VC176  HC04_VC176  HC03_VC177  HC04_VC177  HC03_VC178  HC04_VC178  \
# 2775        25.8         6.8        25.9         7.3        24.7        15.8
# 1976        17.7         4.8        17.8         5.2        17.0         9.3
# 6573        29.9         7.5        31.7         7.3        16.7        17.2
# 3225        11.3         5.0        11.1         5.5        11.9        10.1
# 5346        18.4         6.0        18.3         6.4        19.4        15.6
# 5835         7.2         5.0         8.6         6.0         1.4         3.3
# 4298         4.4         2.2         5.6         2.8         0.4         1.2
# 5222         8.3         2.8         8.1         3.7         8.7         5.1
# 7945        10.8         7.4        11.3         9.3         9.0         6.9
# 4762        25.1         6.7        26.7         6.7        13.7        11.3
#
#       HC03_VC179  HC04_VC179  HC03_VC180  HC04_VC180
# 2775        30.4         7.9        45.2        15.2
# 1976        19.9         6.3        41.4        13.0
# 6573        32.0         8.9        40.1         9.9
# 3225         6.9         6.1        40.2        14.3
# 5346        22.4         9.2        38.2        14.8
# 5835         6.5         6.4        17.4        11.8
# 4298         1.3         1.6        15.1         6.6
# 5222         6.7         3.7        18.9         8.7
# 7945         3.3         4.0        30.6        18.7
# 4762        25.2         8.7        33.5        10.7
#
# [10 rows x 277 columns]

# %% [markdown]
# The data annotation table is inconvenient to browse; I tried to rearrange the format, but the intrinsic nested, hierarchical structure is poorly matched to a flat table.

# %%
def get_kind(c):
    return c.str.split('; ').str.get(0)

def get_description(c):
    descr_full = c.str.split('; ').str.get(1)
    return descr_full.str.split(' - ', expand=True)

def assign_description_columns(df):
    df_descr = get_description(df['fulltext'])
    return df.assign(**df_descr.rename(columns=lambda c: f'descr_{c}'))

def process_ann(df):
    return (df.T
            .rename(columns={0: 'fulltext'})
            .assign(kind=lambda d: get_kind(d.fulltext))
            .pipe(assign_description_columns)
            .drop(columns=['fulltext'])
            .fillna('-')
            .astype('category')
           )

# %%
# pd.read_csv?
ANN = (pd.read_csv(PATH / 'ACS_16_5YR_DP03_ann.csv', nrows=1)
       .pipe(process_ann)
      )

# ANN = ann.pipe(process_ann)
ANN
# Out:
#                                       kind  \
# GEO.id                                  Id
# GEO.id2                                Id2
# GEO.display-label                Geography
# HC03_VC03                          Percent
# HC04_VC03          Percent Margin of Error
# HC03_VC04                          Percent
# HC04_VC04          Percent Margin of Error
# HC03_VC05                          Percent
# HC04_VC05          Percent Margin of Error
# HC03_VC06                          Percent
# HC04_VC06          Percent Margin of Error
# HC03_VC07                          Percent
# HC04_VC07          Percent Margin of Error
# HC03_VC08                          Percent
# HC04_VC08          Percent Margin of Error
# HC03_VC09                          Percent
# HC04_VC09          Percent Margin of Error
# HC03_VC11                          Percent
# HC04_VC11          Percent Margin of Error
# HC03_VC12                          Percent
# HC04_VC12          Percent Margin of Error
# HC03_VC14                          Percent
# HC04_VC14          Percent Margin of Error
# HC03_VC15                          Percent
# HC04_VC15          Percent Margin of Error
# HC03_VC16                          Percent
# HC04_VC16          Percent Margin of Error
# HC03_VC17                          Percent
# HC04_VC17          Percent Margin of Error
# HC03_VC19                          Percent
# ...                                    ...
# HC03_VC165                         Percent
# HC04_VC165         Percent Margin of Error
# HC03_VC166                         Percent
# HC04_VC166         Percent Margin of Error
# HC03_VC167                         Percent
# HC04_VC167         Percent Margin of Error
# HC03_VC168                         Percent
# HC04_VC168         Percent Margin of Error
# HC03_VC169                         Percent
# HC04_VC169         Percent Margin of Error
# HC03_VC171                         Percent
# HC04_VC171         Percent Margin of Error
# HC03_VC172                         Percent
# HC04_VC172         Percent Margin of Error
# HC03_VC173                         Percent
# HC04_VC173         Percent Margin of Error
# HC03_VC174                         Percent
# HC04_VC174         Percent Margin of Error
# HC03_VC175                         Percent
# HC04_VC175         Percent Margin of Error
# HC03_VC176                         Percent
# HC04_VC176         Percent Margin of Error
# HC03_VC177                         Percent
# HC04_VC177         Percent Margin of Error
# HC03_VC178                         Percent
# HC04_VC178         Percent Margin of Error
# HC03_VC179                         Percent
# HC04_VC179         Percent Margin of Error
# HC03_VC180                         Percent
# HC04_VC180         Percent Margin of Error
#
#                                                              descr_0  \
# GEO.id                                                             -
# GEO.id2                                                            -
# GEO.display-label                                                  -
# HC03_VC03                                          EMPLOYMENT STATUS
# HC04_VC03                                          EMPLOYMENT STATUS
# HC03_VC04                                          EMPLOYMENT STATUS
# HC04_VC04                                          EMPLOYMENT STATUS
# HC03_VC05                                          EMPLOYMENT STATUS
# HC04_VC05                                          EMPLOYMENT STATUS
# HC03_VC06                                          EMPLOYMENT STATUS
# HC04_VC06                                          EMPLOYMENT STATUS
# HC03_VC07                                          EMPLOYMENT STATUS
# HC04_VC07                                          EMPLOYMENT STATUS
# HC03_VC08                                          EMPLOYMENT STATUS
# HC04_VC08                                          EMPLOYMENT STATUS
# HC03_VC09                                          EMPLOYMENT STATUS
# HC04_VC09                                          EMPLOYMENT STATUS
# HC03_VC11                                          EMPLOYMENT STATUS
# HC04_VC11                                          EMPLOYMENT STATUS
# HC03_VC12                                          EMPLOYMENT STATUS
# HC04_VC12                                          EMPLOYMENT STATUS
# HC03_VC14                                          EMPLOYMENT STATUS
# HC04_VC14                                          EMPLOYMENT STATUS
# HC03_VC15                                          EMPLOYMENT STATUS
# HC04_VC15                                          EMPLOYMENT STATUS
# HC03_VC16                                          EMPLOYMENT STATUS
# HC04_VC16                                          EMPLOYMENT STATUS
# HC03_VC17                                          EMPLOYMENT STATUS
# HC04_VC17                                          EMPLOYMENT STATUS
# HC03_VC19                                          EMPLOYMENT STATUS
# ...                                                              ...
# HC03_VC165         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC165         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC166         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC166         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC167         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC167         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC168         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC168         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC169         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC169         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC171         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC171         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC172         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC172         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC173         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC173         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC174         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC174         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC175         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC175         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC176         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC176         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC177         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC177         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC178         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC178         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC179         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC179         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC180         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC180         PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
#
#                                                              descr_1  \
# GEO.id                                                             -
# GEO.id2                                                            -
# GEO.display-label                                                  -
# HC03_VC03                               Population 16 years and over
# HC04_VC03                               Population 16 years and over
# HC03_VC04                               Population 16 years and over
# HC04_VC04                               Population 16 years and over
# HC03_VC05                               Population 16 years and over
# HC04_VC05                               Population 16 years and over
# HC03_VC06                               Population 16 years and over
# HC04_VC06                               Population 16 years and over
# HC03_VC07                               Population 16 years and over
# HC04_VC07                               Population 16 years and over
# HC03_VC08                               Population 16 years and over
# HC04_VC08                               Population 16 years and over
# HC03_VC09                               Population 16 years and over
# HC04_VC09                               Population 16 years and over
# HC03_VC11                                       Civilian labor force
# HC04_VC11                                       Civilian labor force
# HC03_VC12                                       Civilian labor force
# HC04_VC12                                       Civilian labor force
# HC03_VC14                                  Females 16 years and over
# HC04_VC14                                  Females 16 years and over
# HC03_VC15                                  Females 16 years and over
# HC04_VC15                                  Females 16 years and over
# HC03_VC16                                  Females 16 years and over
# HC04_VC16                                  Females 16 years and over
# HC03_VC17                                  Females 16 years and over
# HC04_VC17                                  Females 16 years and over
# HC03_VC19              Own children of the householder under 6 years
# ...                                                              ...
# HC03_VC165                                   Married couple families
# HC04_VC165                                   Married couple families
# HC03_VC166                                   Married couple families
# HC04_VC166                                   Married couple families
# HC03_VC167         Families with female householder, no husband p...
# HC04_VC167         Families with female householder, no husband p...
# HC03_VC168         Families with female householder, no husband p...
# HC04_VC168         Families with female householder, no husband p...
# HC03_VC169         Families with female householder, no husband p...
# HC04_VC169         Families with female householder, no husband p...
# HC03_VC171                                                All people
# HC04_VC171                                                All people
# HC03_VC172                                                All people
# HC04_VC172                                                All people
# HC03_VC173                                                All people
# HC04_VC173                                                All people
# HC03_VC174                                                All people
# HC04_VC174                                                All people
# HC03_VC175                                                All people
# HC04_VC175                                                All people
# HC03_VC176                                                All people
# HC04_VC176                                                All people
# HC03_VC177                                                All people
# HC04_VC177                                                All people
# HC03_VC178                                                All people
# HC04_VC178                                                All people
# HC03_VC179                                        People in families
# HC04_VC179                                        People in families
# HC03_VC180                   Unrelated individuals 15 years and over
# HC04_VC180                   Unrelated individuals 15 years and over
#
#                                                              descr_2  \
# GEO.id                                                             -
# GEO.id2                                                            -
# GEO.display-label                                                  -
# HC03_VC03                                                          -
# HC04_VC03                                                          -
# HC03_VC04                                             In labor force
# HC04_VC04                                             In labor force
# HC03_VC05                                             In labor force
# HC04_VC05                                             In labor force
# HC03_VC06                                             In labor force
# HC04_VC06                                             In labor force
# HC03_VC07                                             In labor force
# HC04_VC07                                             In labor force
# HC03_VC08                                             In labor force
# HC04_VC08                                             In labor force
# HC03_VC09                                         Not in labor force
# HC04_VC09                                         Not in labor force
# HC03_VC11                                                          -
# HC04_VC11                                                          -
# HC03_VC12                                          Unemployment Rate
# HC04_VC12                                          Unemployment Rate
# HC03_VC14                                                          -
# HC04_VC14                                                          -
# HC03_VC15                                             In labor force
# HC04_VC15                                             In labor force
# HC03_VC16                                             In labor force
# HC04_VC16                                             In labor force
# HC03_VC17                                             In labor force
# HC04_VC17                                             In labor force
# HC03_VC19                                                          -
# ...                                                              ...
# HC03_VC165         With related children of the householder under...
# HC04_VC165         With related children of the householder under...
# HC03_VC166         With related children of the householder under...
# HC04_VC166         With related children of the householder under...
# HC03_VC167                                                         -
# HC04_VC167                                                         -
# HC03_VC168         With related children of the householder under...
# HC04_VC168         With related children of the householder under...
# HC03_VC169         With related children of the householder under...
# HC04_VC169         With related children of the householder under...
# HC03_VC171                                                         -
# HC04_VC171                                                         -
# HC03_VC172                                            Under 18 years
# HC04_VC172                                            Under 18 years
# HC03_VC173                                            Under 18 years
# HC04_VC173                                            Under 18 years
# HC03_VC174                                            Under 18 years
# HC04_VC174                                            Under 18 years
# HC03_VC175                                            Under 18 years
# HC04_VC175                                            Under 18 years
# HC03_VC176                                         18 years and over
# HC04_VC176                                         18 years and over
# HC03_VC177                                         18 years and over
# HC04_VC177                                         18 years and over
# HC03_VC178                                         18 years and over
# HC04_VC178                                         18 years and over
# HC03_VC179                                                         -
# HC04_VC179                                                         -
# HC03_VC180                                                         -
# HC04_VC180                                                         -
#
#                                                              descr_3  \
# GEO.id                                                             -
# GEO.id2                                                            -
# GEO.display-label                                                  -
# HC03_VC03                                                          -
# HC04_VC03                                                          -
# HC03_VC04                                                          -
# HC04_VC04                                                          -
# HC03_VC05                                       Civilian labor force
# HC04_VC05                                       Civilian labor force
# HC03_VC06                                       Civilian labor force
# HC04_VC06                                       Civilian labor force
# HC03_VC07                                       Civilian labor force
# HC04_VC07                                       Civilian labor force
# HC03_VC08                                               Armed Forces
# HC04_VC08                                               Armed Forces
# HC03_VC09                                                          -
# HC04_VC09                                                          -
# HC03_VC11                                                          -
# HC04_VC11                                                          -
# HC03_VC12                                                          -
# HC04_VC12                                                          -
# HC03_VC14                                                          -
# HC04_VC14                                                          -
# HC03_VC15                                                          -
# HC04_VC15                                                          -
# HC03_VC16                                       Civilian labor force
# HC04_VC16                                       Civilian labor force
# HC03_VC17                                       Civilian labor force
# HC04_VC17                                       Civilian labor force
# HC03_VC19                                                          -
# ...                                                              ...
# HC03_VC165                                                         -
# HC04_VC165                                                         -
# HC03_VC166         With related children of the householder under...
# HC04_VC166         With related children of the householder under...
# HC03_VC167                                                         -
# HC04_VC167                                                         -
# HC03_VC168                                                         -
# HC04_VC168                                                         -
# HC03_VC169         With related children of the householder under...
# HC04_VC169         With related children of the householder under...
# HC03_VC171                                                         -
# HC04_VC171                                                         -
# HC03_VC172                                                         -
# HC04_VC172                                                         -
# HC03_VC173         Related children of the householder under 18 y...
# HC04_VC173         Related children of the householder under 18 y...
# HC03_VC174         Related children of the householder under 18 y...
# HC04_VC174         Related children of the householder under 18 y...
# HC03_VC175         Related children of the householder under 18 y...
# HC04_VC175         Related children of the householder under 18 y...
# HC03_VC176                                                         -
# HC04_VC176                                                         -
# HC03_VC177                                            18 to 64 years
# HC04_VC177                                            18 to 64 years
# HC03_VC178                                         65 years and over
# HC04_VC178                                         65 years and over
# HC03_VC179                                                         -
# HC04_VC179                                                         -
# HC03_VC180                                                         -
# HC04_VC180                                                         -
#
#                                                              descr_4 descr_5
# GEO.id                                                             -       -
# GEO.id2                                                            -       -
# GEO.display-label                                                  -       -
# HC03_VC03                                                          -       -
# HC04_VC03                                                          -       -
# HC03_VC04                                                          -       -
# HC04_VC04                                                          -       -
# HC03_VC05                                                          -       -
# HC04_VC05                                                          -       -
# HC03_VC06                                                   Employed       -
# HC04_VC06                                                   Employed       -
# HC03_VC07                                                 Unemployed       -
# HC04_VC07                                                 Unemployed       -
# HC03_VC08                                                          -       -
# HC04_VC08                                                          -       -
# HC03_VC09                                                          -       -
# HC04_VC09                                                          -       -
# HC03_VC11                                                          -       -
# HC04_VC11                                                          -       -
# HC03_VC12                                                          -       -
# HC04_VC12                                                          -       -
# HC03_VC14                                                          -       -
# HC04_VC14                                                          -       -
# HC03_VC15                                                          -       -
# HC04_VC15                                                          -       -
# HC03_VC16                                                          -       -
# HC04_VC16                                                          -       -
# HC03_VC17                                                   Employed       -
# HC04_VC17                                                   Employed       -
# HC03_VC19                                                          -       -
# ...                                                              ...     ...
# HC03_VC165                                                         -       -
# HC04_VC165                                                         -       -
# HC03_VC166                                                         -       -
# HC04_VC166                                                         -       -
# HC03_VC167                                                         -       -
# HC04_VC167                                                         -       -
# HC03_VC168                                                         -       -
# HC04_VC168                                                         -       -
# HC03_VC169                                                         -       -
# HC04_VC169                                                         -       -
# HC03_VC171                                                         -       -
# HC04_VC171                                                         -       -
# HC03_VC172                                                         -       -
# HC04_VC172                                                         -       -
# HC03_VC173                                                         -       -
# HC04_VC173                                                         -       -
# HC03_VC174         Related children of the householder under 5 years       -
# HC04_VC174         Related children of the householder under 5 years       -
# HC03_VC175         Related children of the householder 5 to 17 years       -
# HC04_VC175         Related children of the householder 5 to 17 years       -
# HC03_VC176                                                         -       -
# HC04_VC176                                                         -       -
# HC03_VC177                                                         -       -
# HC04_VC177                                                         -       -
# HC03_VC178                                                         -       -
# HC04_VC178                                                         -       -
# HC03_VC179                                                         -       -
# HC04_VC179                                                         -       -
# HC03_VC180                                                         -       -
# HC04_VC180                                                         -       -
#
# [277 rows x 7 columns]

# %%
ANN.descr_0.cat.categories
# Out:
# Index(['-', 'CLASS OF WORKER', 'COMMUTING TO WORK', 'EMPLOYMENT STATUS',
#        'HEALTH INSURANCE COVERAGE',
#        'INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTED DOLLARS)', 'INDUSTRY',
#        'OCCUPATION',
#        'PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME IN THE PAST 12 MONTHS IS BELOW THE POVERTY LEVEL'],
#       dtype='object')

# %%
ANN.loc[lambda x: x.descr_0.str.contains('income and benefits', case=False)]
# Out:
#                                kind  \
# HC03_VC74                   Percent
# HC04_VC74   Percent Margin of Error
# HC03_VC75                   Percent
# HC04_VC75   Percent Margin of Error
# HC03_VC76                   Percent
# HC04_VC76   Percent Margin of Error
# HC03_VC77                   Percent
# HC04_VC77   Percent Margin of Error
# HC03_VC78                   Percent
# HC04_VC78   Percent Margin of Error
# HC03_VC79                   Percent
# HC04_VC79   Percent Margin of Error
# HC03_VC80                   Percent
# HC04_VC80   Percent Margin of Error
# HC03_VC81                   Percent
# HC04_VC81   Percent Margin of Error
# HC03_VC82                   Percent
# HC04_VC82   Percent Margin of Error
# HC03_VC83                   Percent
# HC04_VC83   Percent Margin of Error
# HC03_VC84                   Percent
# HC04_VC84   Percent Margin of Error
# HC03_VC85                   Percent
# HC04_VC85   Percent Margin of Error
# HC03_VC86                   Percent
# HC04_VC86   Percent Margin of Error
# HC03_VC89                   Percent
# HC04_VC89   Percent Margin of Error
# HC03_VC90                   Percent
# HC04_VC90   Percent Margin of Error
# ...                             ...
# HC03_VC108                  Percent
# HC04_VC108  Percent Margin of Error
# HC03_VC109                  Percent
# HC04_VC109  Percent Margin of Error
# HC03_VC110                  Percent
# HC04_VC110  Percent Margin of Error
# HC03_VC111                  Percent
# HC04_VC111  Percent Margin of Error
# HC03_VC112                  Percent
# HC04_VC112  Percent Margin of Error
# HC03_VC113                  Percent
# HC04_VC113  Percent Margin of Error
# HC03_VC114                  Percent
# HC04_VC114  Percent Margin of Error
# HC03_VC115                  Percent
# HC04_VC115  Percent Margin of Error
# HC03_VC118                  Percent
# HC04_VC118  Percent Margin of Error
# HC03_VC120                  Percent
# HC04_VC120  Percent Margin of Error
# HC03_VC121                  Percent
# HC04_VC121  Percent Margin of Error
# HC03_VC122                  Percent
# HC04_VC122  Percent Margin of Error
# HC03_VC124                  Percent
# HC04_VC124  Percent Margin of Error
# HC03_VC125                  Percent
# HC04_VC125  Percent Margin of Error
# HC03_VC126                  Percent
# HC04_VC126  Percent Margin of Error
#
#                                                       descr_0  \
# HC03_VC74   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC74   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC75   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC75   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC76   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC76   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC77   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC77   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC78   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC78   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC79   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC79   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC80   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC80   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC81   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC81   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC82   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC82   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC83   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC83   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC84   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC84   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC85   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC85   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC86   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC86   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC89   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC89   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC90   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC90   INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# ...                                                       ...
# HC03_VC108  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC108  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC109  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC109  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC110  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC110  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC111  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC111  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC112  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC112  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC113  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC113  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC114  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC114  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC115  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC115  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC118  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC118  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC120  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC120  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC121  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC121  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC122  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC122  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC124  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC124  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC125  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC125  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC03_VC126  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
# HC04_VC126  INCOME AND BENEFITS (IN 2016 INFLATION-ADJUSTE...
#
#                                                       descr_1  \
# HC03_VC74                                    Total households
# HC04_VC74                                    Total households
# HC03_VC75                                    Total households
# HC04_VC75                                    Total households
# HC03_VC76                                    Total households
# HC04_VC76                                    Total households
# HC03_VC77                                    Total households
# HC04_VC77                                    Total households
# HC03_VC78                                    Total households
# HC04_VC78                                    Total households
# HC03_VC79                                    Total households
# HC04_VC79                                    Total households
# HC03_VC80                                    Total households
# HC04_VC80                                    Total households
# HC03_VC81                                    Total households
# HC04_VC81                                    Total households
# HC03_VC82                                    Total households
# HC04_VC82                                    Total households
# HC03_VC83                                    Total households
# HC04_VC83                                    Total households
# HC03_VC84                                    Total households
# HC04_VC84                                    Total households
# HC03_VC85                                    Total households
# HC04_VC85                                    Total households
# HC03_VC86                                    Total households
# HC04_VC86                                    Total households
# HC03_VC89                                       With earnings
# HC04_VC89                                       With earnings
# HC03_VC90                                       With earnings
# HC04_VC90                                       With earnings
# ...                                                       ...
# HC03_VC108                                           Families
# HC04_VC108                                           Families
# HC03_VC109                                           Families
# HC04_VC109                                           Families
# HC03_VC110                                           Families
# HC04_VC110                                           Families
# HC03_VC111                                           Families
# HC04_VC111                                           Families
# HC03_VC112                                           Families
# HC04_VC112                                           Families
# HC03_VC113                                           Families
# HC04_VC113                                           Families
# HC03_VC114                                           Families
# HC04_VC114                                           Families
# HC03_VC115                                           Families
# HC04_VC115                                           Families
# HC03_VC118                        Per capita income (dollars)
# HC04_VC118                        Per capita income (dollars)
# HC03_VC120                               Nonfamily households
# HC04_VC120                               Nonfamily households
# HC03_VC121                               Nonfamily households
# HC04_VC121                               Nonfamily households
# HC03_VC122                               Nonfamily households
# HC04_VC122                               Nonfamily households
# HC03_VC124              Median earnings for workers (dollars)
# HC04_VC124              Median earnings for workers (dollars)
# HC03_VC125  Median earnings for male full-time, year-round...
# HC04_VC125  Median earnings for male full-time, year-round...
# HC03_VC126  Median earnings for female full-time, year-rou...
# HC04_VC126  Median earnings for female full-time, year-rou...
#
#                                       descr_2 descr_3 descr_4 descr_5
# HC03_VC74                                   -       -       -       -
# HC04_VC74                                   -       -       -       -
# HC03_VC75                   Less than $10,000       -       -       -
# HC04_VC75                   Less than $10,000       -       -       -
# HC03_VC76                  $10,000 to $14,999       -       -       -
# HC04_VC76                  $10,000 to $14,999       -       -       -
# HC03_VC77                  $15,000 to $24,999       -       -       -
# HC04_VC77                  $15,000 to $24,999       -       -       -
# HC03_VC78                  $25,000 to $34,999       -       -       -
# HC04_VC78                  $25,000 to $34,999       -       -       -
# HC03_VC79                  $35,000 to $49,999       -       -       -
# HC04_VC79                  $35,000 to $49,999       -       -       -
# HC03_VC80                  $50,000 to $74,999       -       -       -
# HC04_VC80                  $50,000 to $74,999       -       -       -
# HC03_VC81                  $75,000 to $99,999       -       -       -
# HC04_VC81                  $75,000 to $99,999       -       -       -
# HC03_VC82                $100,000 to $149,999       -       -       -
# HC04_VC82                $100,000 to $149,999       -       -       -
# HC03_VC83                $150,000 to $199,999       -       -       -
# HC04_VC83                $150,000 to $199,999       -       -       -
# HC03_VC84                    $200,000 or more       -       -       -
# HC04_VC84                    $200,000 or more       -       -       -
# HC03_VC85   Median household income (dollars)       -       -       -
# HC04_VC85   Median household income (dollars)       -       -       -
# HC03_VC86     Mean household income (dollars)       -       -       -
# HC04_VC86     Mean household income (dollars)       -       -       -
# HC03_VC89                                   -       -       -       -
# HC04_VC89                                   -       -       -       -
# HC03_VC90             Mean earnings (dollars)       -       -       -
# HC04_VC90             Mean earnings (dollars)       -       -       -
# ...                                       ...     ...     ...     ...
# HC03_VC108                 $35,000 to $49,999       -       -       -
# HC04_VC108                 $35,000 to $49,999       -       -       -
# HC03_VC109                 $50,000 to $74,999       -       -       -
# HC04_VC109                 $50,000 to $74,999       -       -       -
# HC03_VC110                 $75,000 to $99,999       -       -       -
# HC04_VC110                 $75,000 to $99,999       -       -       -
# HC03_VC111               $100,000 to $149,999       -       -       -
# HC04_VC111               $100,000 to $149,999       -       -       -
# HC03_VC112               $150,000 to $199,999       -       -       -
# HC04_VC112               $150,000 to $199,999       -       -       -
# HC03_VC113                   $200,000 or more       -       -       -
# HC04_VC113                   $200,000 or more       -       -       -
# HC03_VC114     Median family income (dollars)       -       -       -
# HC04_VC114     Median family income (dollars)       -       -       -
# HC03_VC115       Mean family income (dollars)       -       -       -
# HC04_VC115       Mean family income (dollars)       -       -       -
# HC03_VC118                                  -       -       -       -
# HC04_VC118                                  -       -       -       -
# HC03_VC120                                  -       -       -       -
# HC04_VC120                                  -       -       -       -
# HC03_VC121  Median nonfamily income (dollars)       -       -       -
# HC04_VC121  Median nonfamily income (dollars)       -       -       -
# HC03_VC122    Mean nonfamily income (dollars)       -       -       -
# HC04_VC122    Mean nonfamily income (dollars)       -       -       -
# HC03_VC124                                  -       -       -       -
# HC04_VC124                                  -       -       -       -
# HC03_VC125                                  -       -       -       -
# HC04_VC125                                  -       -       -       -
# HC03_VC126                                  -       -       -       -
# HC04_VC126                                  -       -       -       -
#
# [88 rows x 7 columns]

# %%
ANN.loc[lambda x: x.descr_0.str.contains('health', case=False)]
# Out:
#                                kind                    descr_0  \
# HC03_VC130                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC130  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC131                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC131  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC132                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC132  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC133                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC133  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC134                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC134  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC137                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC137  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC138                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC138  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC141                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC141  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC142                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC142  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC143                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC143  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC144                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC144  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC145                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC145  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC146                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC146  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC147                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC147  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC148                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC148  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC149                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC149  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC150                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC150  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC151                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC151  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC152                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC152  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC153                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC153  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC154                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC154  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC155                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC155  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC156                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC156  Percent Margin of Error  HEALTH INSURANCE COVERAGE
# HC03_VC157                  Percent  HEALTH INSURANCE COVERAGE
# HC04_VC157  Percent Margin of Error  HEALTH INSURANCE COVERAGE
#
#                                                       descr_1  \
# HC03_VC130           Civilian noninstitutionalized population
# HC04_VC130           Civilian noninstitutionalized population
# HC03_VC131           Civilian noninstitutionalized population
# HC04_VC131           Civilian noninstitutionalized population
# HC03_VC132           Civilian noninstitutionalized population
# HC04_VC132           Civilian noninstitutionalized population
# HC03_VC133           Civilian noninstitutionalized population
# HC04_VC133           Civilian noninstitutionalized population
# HC03_VC134           Civilian noninstitutionalized population
# HC04_VC134           Civilian noninstitutionalized population
# HC03_VC137  Civilian noninstitutionalized population under...
# HC04_VC137  Civilian noninstitutionalized population under...
# HC03_VC138  Civilian noninstitutionalized population under...
# HC04_VC138  Civilian noninstitutionalized population under...
# HC03_VC141  Civilian noninstitutionalized population 18 to...
# HC04_VC141  Civilian noninstitutionalized population 18 to...
# HC03_VC142  Civilian noninstitutionalized population 18 to...
# HC04_VC142  Civilian noninstitutionalized population 18 to...
# HC03_VC143  Civilian noninstitutionalized population 18 to...
# HC04_VC143  Civilian noninstitutionalized population 18 to...
# HC03_VC144  Civilian noninstitutionalized population 18 to...
# HC04_VC144  Civilian noninstitutionalized population 18 to...
# HC03_VC145  Civilian noninstitutionalized population 18 to...
# HC04_VC145  Civilian noninstitutionalized population 18 to...
# HC03_VC146  Civilian noninstitutionalized population 18 to...
# HC04_VC146  Civilian noninstitutionalized population 18 to...
# HC03_VC147  Civilian noninstitutionalized population 18 to...
# HC04_VC147  Civilian noninstitutionalized population 18 to...
# HC03_VC148  Civilian noninstitutionalized population 18 to...
# HC04_VC148  Civilian noninstitutionalized population 18 to...
# HC03_VC149  Civilian noninstitutionalized population 18 to...
# HC04_VC149  Civilian noninstitutionalized population 18 to...
# HC03_VC150  Civilian noninstitutionalized population 18 to...
# HC04_VC150  Civilian noninstitutionalized population 18 to...
# HC03_VC151  Civilian noninstitutionalized population 18 to...
# HC04_VC151  Civilian noninstitutionalized population 18 to...
# HC03_VC152  Civilian noninstitutionalized population 18 to...
# HC04_VC152  Civilian noninstitutionalized population 18 to...
# HC03_VC153  Civilian noninstitutionalized population 18 to...
# HC04_VC153  Civilian noninstitutionalized population 18 to...
# HC03_VC154  Civilian noninstitutionalized population 18 to...
# HC04_VC154  Civilian noninstitutionalized population 18 to...
# HC03_VC155  Civilian noninstitutionalized population 18 to...
# HC04_VC155  Civilian noninstitutionalized population 18 to...
# HC03_VC156  Civilian noninstitutionalized population 18 to...
# HC04_VC156  Civilian noninstitutionalized population 18 to...
# HC03_VC157  Civilian noninstitutionalized population 18 to...
# HC04_VC157  Civilian noninstitutionalized population 18 to...
#
#                                    descr_2                         descr_3  \
# HC03_VC130                               -                               -
# HC04_VC130                               -                               -
# HC03_VC131  With health insurance coverage                               -
# HC04_VC131  With health insurance coverage                               -
# HC03_VC132  With health insurance coverage   With private health insurance
# HC04_VC132  With health insurance coverage   With private health insurance
# HC03_VC133  With health insurance coverage            With public coverage
# HC04_VC133  With health insurance coverage            With public coverage
# HC03_VC134    No health insurance coverage                               -
# HC04_VC134    No health insurance coverage                               -
# HC03_VC137                               -                               -
# HC04_VC137                               -                               -
# HC03_VC138    No health insurance coverage                               -
# HC04_VC138    No health insurance coverage                               -
# HC03_VC141                               -                               -
# HC04_VC141                               -                               -
# HC03_VC142                 In labor force:                               -
# HC04_VC142                 In labor force:                               -
# HC03_VC143                 In labor force:                       Employed:
# HC04_VC143                 In labor force:                       Employed:
# HC03_VC144                 In labor force:                       Employed:
# HC04_VC144                 In labor force:                       Employed:
# HC03_VC145                 In labor force:                       Employed:
# HC04_VC145                 In labor force:                       Employed:
# HC03_VC146                 In labor force:                       Employed:
# HC04_VC146                 In labor force:                       Employed:
# HC03_VC147                 In labor force:                       Employed:
# HC04_VC147                 In labor force:                       Employed:
# HC03_VC148                 In labor force:                     Unemployed:
# HC04_VC148                 In labor force:                     Unemployed:
# HC03_VC149                 In labor force:                     Unemployed:
# HC04_VC149                 In labor force:                     Unemployed:
# HC03_VC150                 In labor force:                     Unemployed:
# HC04_VC150                 In labor force:                     Unemployed:
# HC03_VC151                 In labor force:                     Unemployed:
# HC04_VC151                 In labor force:                     Unemployed:
# HC03_VC152                 In labor force:                     Unemployed:
# HC04_VC152                 In labor force:                     Unemployed:
# HC03_VC153             Not in labor force:                               -
# HC04_VC153             Not in labor force:                               -
# HC03_VC154             Not in labor force:  With health insurance coverage
# HC04_VC154             Not in labor force:  With health insurance coverage
# HC03_VC155             Not in labor force:  With health insurance coverage
# HC04_VC155             Not in labor force:  With health insurance coverage
# HC03_VC156             Not in labor force:  With health insurance coverage
# HC04_VC156             Not in labor force:  With health insurance coverage
# HC03_VC157             Not in labor force:    No health insurance coverage
# HC04_VC157             Not in labor force:    No health insurance coverage
#
#                                    descr_4                        descr_5
# HC03_VC130                               -                              -
# HC04_VC130                               -                              -
# HC03_VC131                               -                              -
# HC04_VC131                               -                              -
# HC03_VC132                               -                              -
# HC04_VC132                               -                              -
# HC03_VC133                               -                              -
# HC04_VC133                               -                              -
# HC03_VC134                               -                              -
# HC04_VC134                               -                              -
# HC03_VC137                               -                              -
# HC04_VC137                               -                              -
# HC03_VC138                               -                              -
# HC04_VC138                               -                              -
# HC03_VC141                               -                              -
# HC04_VC141                               -                              -
# HC03_VC142                               -                              -
# HC04_VC142                               -                              -
# HC03_VC143                               -                              -
# HC04_VC143                               -                              -
# HC03_VC144  With health insurance coverage                              -
# HC04_VC144  With health insurance coverage                              -
# HC03_VC145  With health insurance coverage  With private health insurance
# HC04_VC145  With health insurance coverage  With private health insurance
# HC03_VC146  With health insurance coverage           With public coverage
# HC04_VC146  With health insurance coverage           With public coverage
# HC03_VC147    No health insurance coverage                              -
# HC04_VC147    No health insurance coverage                              -
# HC03_VC148                               -                              -
# HC04_VC148                               -                              -
# HC03_VC149  With health insurance coverage                              -
# HC04_VC149  With health insurance coverage                              -
# HC03_VC150  With health insurance coverage  With private health insurance
# HC04_VC150  With health insurance coverage  With private health insurance
# HC03_VC151  With health insurance coverage           With public coverage
# HC04_VC151  With health insurance coverage           With public coverage
# HC03_VC152    No health insurance coverage                              -
# HC04_VC152    No health insurance coverage                              -
# HC03_VC153                               -                              -
# HC04_VC153                               -                              -
# HC03_VC154                               -                              -
# HC04_VC154                               -                              -
# HC03_VC155   With private health insurance                              -
# HC04_VC155   With private health insurance                              -
# HC03_VC156            With public coverage                              -
# HC04_VC156            With public coverage                              -
# HC03_VC157                               -                              -
# HC04_VC157                               -                              -

# %%
ANN.loc[lambda x: x.descr_0.str.contains('poverty', case=False)]
# Out:
#                                kind  \
# HC03_VC161                  Percent
# HC04_VC161  Percent Margin of Error
# HC03_VC162                  Percent
# HC04_VC162  Percent Margin of Error
# HC03_VC163                  Percent
# HC04_VC163  Percent Margin of Error
# HC03_VC164                  Percent
# HC04_VC164  Percent Margin of Error
# HC03_VC165                  Percent
# HC04_VC165  Percent Margin of Error
# HC03_VC166                  Percent
# HC04_VC166  Percent Margin of Error
# HC03_VC167                  Percent
# HC04_VC167  Percent Margin of Error
# HC03_VC168                  Percent
# HC04_VC168  Percent Margin of Error
# HC03_VC169                  Percent
# HC04_VC169  Percent Margin of Error
# HC03_VC171                  Percent
# HC04_VC171  Percent Margin of Error
# HC03_VC172                  Percent
# HC04_VC172  Percent Margin of Error
# HC03_VC173                  Percent
# HC04_VC173  Percent Margin of Error
# HC03_VC174                  Percent
# HC04_VC174  Percent Margin of Error
# HC03_VC175                  Percent
# HC04_VC175  Percent Margin of Error
# HC03_VC176                  Percent
# HC04_VC176  Percent Margin of Error
# HC03_VC177                  Percent
# HC04_VC177  Percent Margin of Error
# HC03_VC178                  Percent
# HC04_VC178  Percent Margin of Error
# HC03_VC179                  Percent
# HC04_VC179  Percent Margin of Error
# HC03_VC180                  Percent
# HC04_VC180  Percent Margin of Error
#
#                                                       descr_0  \
# HC03_VC161  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC161  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC162  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC162  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC163  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC163  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC164  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC164  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC165  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC165  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC166  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC166  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC167  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC167  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC168  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC168  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC169  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC169  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC171  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC171  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC172  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC172  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC173  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC173  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC174  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC174  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC175  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC175  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC176  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC176  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC177  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC177  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC178  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC178  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC179  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC179  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC03_VC180  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
# HC04_VC180  PERCENTAGE OF FAMILIES AND PEOPLE WHOSE INCOME...
#
#                                                       descr_1  \
# HC03_VC161                                       All families
# HC04_VC161                                       All families
# HC03_VC162                                       All families
# HC04_VC162                                       All families
# HC03_VC163                                       All families
# HC04_VC163                                       All families
# HC03_VC164                            Married couple families
# HC04_VC164                            Married couple families
# HC03_VC165                            Married couple families
# HC04_VC165                            Married couple families
# HC03_VC166                            Married couple families
# HC04_VC166                            Married couple families
# HC03_VC167  Families with female householder, no husband p...
# HC04_VC167  Families with female householder, no husband p...
# HC03_VC168  Families with female householder, no husband p...
# HC04_VC168  Families with female householder, no husband p...
# HC03_VC169  Families with female householder, no husband p...
# HC04_VC169  Families with female householder, no husband p...
# HC03_VC171                                         All people
# HC04_VC171                                         All people
# HC03_VC172                                         All people
# HC04_VC172                                         All people
# HC03_VC173                                         All people
# HC04_VC173                                         All people
# HC03_VC174                                         All people
# HC04_VC174                                         All people
# HC03_VC175                                         All people
# HC04_VC175                                         All people
# HC03_VC176                                         All people
# HC04_VC176                                         All people
# HC03_VC177                                         All people
# HC04_VC177                                         All people
# HC03_VC178                                         All people
# HC04_VC178                                         All people
# HC03_VC179                                 People in families
# HC04_VC179                                 People in families
# HC03_VC180            Unrelated individuals 15 years and over
# HC04_VC180            Unrelated individuals 15 years and over
#
#                                                       descr_2  \
# HC03_VC161                                                  -
# HC04_VC161                                                  -
# HC03_VC162  With related children of the householder under...
# HC04_VC162  With related children of the householder under...
# HC03_VC163  With related children of the householder under...
# HC04_VC163  With related children of the householder under...
# HC03_VC164                                                  -
# HC04_VC164                                                  -
# HC03_VC165  With related children of the householder under...
# HC04_VC165  With related children of the householder under...
# HC03_VC166  With related children of the householder under...
# HC04_VC166  With related children of the householder under...
# HC03_VC167                                                  -
# HC04_VC167                                                  -
# HC03_VC168  With related children of the householder under...
# HC04_VC168  With related children of the householder under...
# HC03_VC169  With related children of the householder under...
# HC04_VC169  With related children of the householder under...
# HC03_VC171                                                  -
# HC04_VC171                                                  -
# HC03_VC172                                     Under 18 years
# HC04_VC172                                     Under 18 years
# HC03_VC173                                     Under 18 years
# HC04_VC173                                     Under 18 years
# HC03_VC174                                     Under 18 years
# HC04_VC174                                     Under 18 years
# HC03_VC175                                     Under 18 years
# HC04_VC175                                     Under 18 years
# HC03_VC176                                  18 years and over
# HC04_VC176                                  18 years and over
# HC03_VC177                                  18 years and over
# HC04_VC177                                  18 years and over
# HC03_VC178                                  18 years and over
# HC04_VC178                                  18 years and over
# HC03_VC179                                                  -
# HC04_VC179                                                  -
# HC03_VC180                                                  -
# HC04_VC180                                                  -
#
#                                                       descr_3  \
# HC03_VC161                                                  -
# HC04_VC161                                                  -
# HC03_VC162                                                  -
# HC04_VC162                                                  -
# HC03_VC163  With related children of the householder under...
# HC04_VC163  With related children of the householder under...
# HC03_VC164                                                  -
# HC04_VC164                                                  -
# HC03_VC165                                                  -
# HC04_VC165                                                  -
# HC03_VC166  With related children of the householder under...
# HC04_VC166  With related children of the householder under...
# HC03_VC167                                                  -
# HC04_VC167                                                  -
# HC03_VC168                                                  -
# HC04_VC168                                                  -
# HC03_VC169  With related children of the householder under...
# HC04_VC169  With related children of the householder under...
# HC03_VC171                                                  -
# HC04_VC171                                                  -
# HC03_VC172                                                  -
# HC04_VC172                                                  -
# HC03_VC173  Related children of the householder under 18 y...
# HC04_VC173  Related children of the householder under 18 y...
# HC03_VC174  Related children of the householder under 18 y...
# HC04_VC174  Related children of the householder under 18 y...
# HC03_VC175  Related children of the householder under 18 y...
# HC04_VC175  Related children of the householder under 18 y...
# HC03_VC176                                                  -
# HC04_VC176                                                  -
# HC03_VC177                                     18 to 64 years
# HC04_VC177                                     18 to 64 years
# HC03_VC178                                  65 years and over
# HC04_VC178                                  65 years and over
# HC03_VC179                                                  -
# HC04_VC179                                                  -
# HC03_VC180                                                  -
# HC04_VC180                                                  -
#
#                                                       descr_4 descr_5
# HC03_VC161                                                  -       -
# HC04_VC161                                                  -       -
# HC03_VC162                                                  -       -
# HC04_VC162                                                  -       -
# HC03_VC163                                                  -       -
# HC04_VC163                                                  -       -
# HC03_VC164                                                  -       -
# HC04_VC164                                                  -       -
# HC03_VC165                                                  -       -
# HC04_VC165                                                  -       -
# HC03_VC166                                                  -       -
# HC04_VC166                                                  -       -
# HC03_VC167                                                  -       -
# HC04_VC167                                                  -       -
# HC03_VC168                                                  -       -
# HC04_VC168                                                  -       -
# HC03_VC169                                                  -       -
# HC04_VC169                                                  -       -
# HC03_VC171                                                  -       -
# HC04_VC171                                                  -       -
# HC03_VC172                                                  -       -
# HC04_VC172                                                  -       -
# HC03_VC173                                                  -       -
# HC04_VC173                                                  -       -
# HC03_VC174  Related children of the householder under 5 years       -
# HC04_VC174  Related children of the householder under 5 years       -
# HC03_VC175  Related children of the householder 5 to 17 years       -
# HC04_VC175  Related children of the householder 5 to 17 years       -
# HC03_VC176                                                  -       -
# HC04_VC176                                                  -       -
# HC03_VC177                                                  -       -
# HC04_VC177                                                  -       -
# HC03_VC178                                                  -       -
# HC04_VC178                                                  -       -
# HC03_VC179                                                  -       -
# HC04_VC179                                                  -       -
# HC03_VC180                                                  -       -
# HC04_VC180                                                  -       -

# %% [markdown]
# After (manually) finding the indices for the desired observables, we build a subtable containing only this information, with column labels matching our application.

# %%
COLUMNS = {
    'GEO.id2': 'geoid',
    'GEO.display-label': 'label',
    'HC03_VC12': 'rate_unemployed',
    'HC03_VC179': 'rate_underpovlimit_families',
    'HC03_VC157': 'rate_no_health_insurance_unemployed',
}

def get_data_subset(df, col_map):
    cols_to_keep = list(col_map.keys())
    print(cols_to_keep)
    return df[cols_to_keep].rename(columns=col_map)

# %%
data.pipe(get_data_subset, COLUMNS).nlargest(20, 'rate_no_health_insurance_unemployed')
# Out:
# ['GEO.id2', 'GEO.display-label', 'HC03_VC12', 'HC03_VC179', 'HC03_VC157']
#            geoid                                              label  \
# 1733  6037208904  Census Tract 2089.04, Los Angeles County, Cali...
# 6480  6075980600  Census Tract 9806, San Francisco County, Calif...
# 4602  6065041500     Census Tract 415, Riverside County, California
# 1631  6037194402  Census Tract 1944.02, Los Angeles County, Cali...
# 1734  6037209102  Census Tract 2091.02, Los Angeles County, Cali...
# 4484  6061022300        Census Tract 223, Placer County, California
# 5745  6073003902   Census Tract 39.02, San Diego County, California
# 1763  6037211804  Census Tract 2118.04, Los Angeles County, Cali...
# 1727  6037208710  Census Tract 2087.10, Los Angeles County, Cali...
# 1772  6037212303  Census Tract 2123.03, Los Angeles County, Cali...
# 1879  6037228100  Census Tract 2281, Los Angeles County, California
# 3172  6037602900  Census Tract 6029, Los Angeles County, California
# 932   6025010101   Census Tract 101.01, Imperial County, California
# 4418  6061020106     Census Tract 201.06, Placer County, California
# 5353  6071001503  Census Tract 15.03, San Bernardino County, Cal...
# 1240  6037109400  Census Tract 1094, Los Angeles County, California
# 7895  6111004503     Census Tract 45.03, Ventura County, California
# 2745  6037532700  Census Tract 5327, Los Angeles County, California
# 1884  6037228410  Census Tract 2284.10, Los Angeles County, Cali...
# 1608  6037191610  Census Tract 1916.10, Los Angeles County, Cali...
#
#       rate_unemployed  rate_underpovlimit_families  \
# 1733              8.2                         69.7
# 6480             14.1                         42.5
# 4602              5.3                         23.6
# 1631              4.1                          5.2
# 1734              5.2                         55.3
# 4484              0.0                          5.9
# 5745             17.7                         37.7
# 1763             10.2                         35.4
# 1727              6.2                         18.2
# 1772              9.1                         39.6
# 1879              6.7                         25.5
# 3172             13.0                         18.4
# 932               7.5                          0.0
# 4418              6.2                          7.2
# 5353             14.6                         31.9
# 1240              5.2                         16.8
# 7895              7.7                         17.1
# 2745             12.9                         19.3
# 1884             10.4                         34.6
# 1608              9.2                         24.2
#
#       rate_no_health_insurance_unemployed
# 1733                                 71.6
# 6480                                 70.5
# 4602                                 68.3
# 1631                                 67.2
# 1734                                 64.5
# 4484                                 62.8
# 5745                                 60.2
# 1763                                 60.0
# 1727                                 58.0
# 1772                                 57.5
# 1879                                 57.4
# 3172                                 56.6
# 932                                  56.1
# 4418                                 56.0
# 5353                                 55.1
# 1240                                 54.9
# 7895                                 54.9
# 2745                                 54.5
# 1884                                 54.3
# 1608                                 53.9

# %% [markdown]
# And now we add that as a dataset:

# %%
from cawc import datasets as ds

ds.DEMO_ECON
# Out:
# - `sea2016-A`: _from American Factfinder Selected Economic Characteristics 2012-2016 (CT level)_
